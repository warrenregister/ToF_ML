# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sys import path
# %matplotlib inline

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# %cd /content/drive/MyDrive/PHI/ToF_ML/src
# Out:
# /content/drive/MyDrive/PHI/ToF_ML/src

# %%
from data_transformation import get_frags
spots = get_frags()['FragmentMass']

# %%
def C(channels, spec_bin_size, start_time,  mass_over_time, mass_offset):
    return ((np.array(channels) * .001 * spec_bin_size + start_time) * mass_over_time + mass_offset)**2

# %%
df_read = pd.read_csv('../data/ssl_csvs_converted_to_df.csv')
from ast import literal_eval
df_read['intensities'] = df_read['intensities'].apply(literal_eval)
df_read['channels'] = df_read['channels'].apply(literal_eval)

# %%
df_read.head()
# Out:
#       file_name  ...                                           channels
# 0  C0059-V1.cas  ...  [12729.6134, 13388.07292, 14021.38724, 14625.2...
# 1  C0060-V1.cas  ...  [12773.45818, 13433.49441, 13495.05187, 14068....
# 2  C0061-U1.cas  ...  [12779.34033, 13440.22492, 14076.03163, 14689....
# 3  C0061-V1.cas  ...  [1381.98178, 1400.517, 1412.53457, 1440.11759,...
# 4  C0062-U1.cas  ...  [12795.06881, 13456.57005, 14092.96684, 14707....
#
# [5 rows x 8 columns]

# %%
from data_transformation import mass_formula
def generate_calibrated_data(data, numba=False):
    '''
    Applies mass_formula to every row in dataset to allow
    calibrated graphs to be generated.
    '''
    new_data = data.copy()
    masses = []
    for row in new_data.itertuples():
        spec = row.SpecBinSize
        m_over_t = row.MassOverTime
        m_offset = row.MassOffset
        time = row.StartFlightTime
        if not numba:
            masses.append(mass_formula(np.array(row.channels), spec, time,
                          m_over_t, m_offset))
        else:
            masses.append(numba_mass_formula(np.array(row.channels), spec,
                          time, m_over_t, m_offset))
    new_data['masses'] = masses
    return new_data

# %%
from data_transformation import get_fragment_stats, generate_calibrated_data
df_read = generate_calibrated_data(df_read[df_read['channels'].apply(len)> 0])
df_read.reset_index(inplace=True)

# %%
df_read.head()
# Out:
#    index  ...                                             masses
# 0      0  ...  [12.004495885110552, 13.012398275521816, 14.02...
# 1      1  ...  [12.004681147019333, 13.01242014410188, 13.108...
# 2      2  ...  [12.003062954788383, 13.010939902638805, 14.01...
# 3      3  ...  [1.016159799036636, 1.024261311539043, 1.02953...
# 4      4  ...  [12.002858579352937, 13.010660285835183, 14.01...
#
# [5 rows x 10 columns]

# %%
df = get_fragment_stats(df_read, prop_name='proportions_peaks_identified')

# %%
df.to_csv('../data/new_1900_without_peakless_spectra.csv', index=False)

# %%
a = df['index']
df.drop('index', axis=1, inplace=True)
df['index'] = a

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   file_name                              1911 non-null   object
#  1   technique                              1911 non-null   object
#  2   StartFlightTime                        1911 non-null   float64
#  3   MassOverTime                           1911 non-null   float64
#  4   MassOffset                             1911 non-null   float64
#  5   SpecBinSize                            1911 non-null   float64
#  6   intensities                            1911 non-null   object
#  7   channels                               1911 non-null   object
#  8   masses                                 1911 non-null   object
#  9   avg_dist_frags_low                     1911 non-null   float64
#  10  avg_dist_frags_high                    1911 non-null   float64
#  11  adjusted_proportions_peaks_identified  1911 non-null   float64
#  12  proportions_peaks_identified           1911 non-null   float64
#  13  diff                                   1911 non-null   float64
#  14  prop_diff_in_low                       1900 non-null   float64
#  15  calibration                            1911 non-null   int64
#  16  index                                  1911 non-null   int64
# dtypes: float64(10), int64(2), object(5)
# memory usage: 253.9+ KB

# %%
df.head()
# Out:
#       file_name  technique  ...  calibration  index
# 0  C0059-V1.cas   -TofSIMS  ...            0      0
# 1  C0060-V1.cas   -TofSIMS  ...            0      1
# 2  C0061-U1.cas   +TofSIMS  ...            0      2
# 3  C0061-V1.cas   -TofSIMS  ...            0      3
# 4  C0062-U1.cas   +TofSIMS  ...            0      4
#
# [5 rows x 17 columns]

# %%
def recalibrate(row, spots, slope_amt=0, offset_amt=0, num_peaks=False):
    '''
    Function which quickly asseses the calibration of a spectrum.
    '''
    slope = row.MassOverTime + slope_amt *  row.MassOverTime
    offset = row.MassOffset + offset_amt * row.MassOffset
    peaks = []
    peaks = mass_formula(np.array(row.channels), row.SpecBinSize, row.StartFlightTime, slope,
                   offset)
    masses, frags1, dist1, masses2, frags2, dist2 = get_frags_dists(peaks,
                                                                    spots,
                                                                    [.003,.007])
    prop = len(masses) / len(peaks[peaks<336])
    low_dist = 0
    high_dist = 0
    if len(dist1) > 0:
        low_dist = np.mean(dist1)
    if len(dist2) > 0:
        high_dist = np.mean(dist2)
    if num_peaks:
        return prop, low_dist, high_dist, len(masses)
    else:
        return prop, low_dist, high_dist

# %%
from data_transformation import get_frags_dists

# %%
def get_best_offset(spectrum, slope_range, offset_range, prev=0,
                    offsets=30, slopes=20, first=True, frags=None):
    '''
    Find best amount of slope/offset to add/subtract to slope/offset value
    to achieve the optimal calibration for spectrum. Calibration is measured
    using mass fragments. A spectrum which more matches to known masses is more
    calibrated than one with fewer. A spectrum whose matches are very close to
    known mass is more calibrated than one that is further away.

    Arguments -------
    spectrum: row from dataframe containing information on a spectrum
    slope_range: data structure containing min, max slope to try, slope erros
                 are typically smaller than offset errors.
    offset_range: data structure containing min, max offset agumentation
                       to try. This method shrinks the range iteratively until
                       the best offset is achieved.
    spots: a list of mass fragments
    '''
    if first:
        print('optimizing ' + spectrum.file_name)
        print('initial proportion: ' + str(spectrum.proportions_peaks_identified))
    if not isinstance(frags, pd.Series):
        frags = get_frags()
    proportions = [0]
    low_distances = []
    high_distances = []
    best_prop = 0
    best_offset = spectrum.MassOffset
    best_slope = spectrum[2]
    best_ld = 1
    best_hd = 1
    ys = [] 
    i = 0
    mults = [1, -1]
    slope_space = np.linspace(slope_range[0], slope_range[1], slopes)
    while 1:
        slope = slope_space[i]
        for slope_mult in mults:
            slope_val = slope * slope_mult
            props = []
            low_dists = []
            high_dists = []
            y = []
            space = np.linspace(offset_range[0], offset_range[1], offsets)
            j = 0
            changed = False
            while 1:
                offset = space[j]
                for mult in mults:
                    improved = False
                    val = mult * offset
                    y.append(val)
                    prop, low, high = recalibrate(spectrum, frags, slope_val, val)
                    if prop > best_prop:
                        improved=True
                    elif (prop == best_prop and best_hd - high > 0 and
                          best_ld - low > 0):
                        improved = True
                    props.append(prop)
                    low_dists.append(low)
                    high_dists.append(high)
                    if improved:
                        best_prop = prop 
                        best_offset = val
                        best_slope = slope_val
                        best_ld = low
                        best_hd = high
                        edge = (np.where(space == mult * best_offset)[0][0] + .1)/ len(space)
                        edge = 2 * abs(.5 - edge)
                        slope_edge = np.where(slope_space == slope_mult * best_slope)[0][0]
                        slope_edge = 2 * abs(.5 - (slope_edge + .1) / len(slope_space))
                        changed = True            
                j += 1
                if j >= len(space):
                    break
            if changed:
                ys = y 
                proportions = props 
                low_distances = low_dists
                high_distances = high_dists
        i += 1
        if i >= len(slope_space):
            break
    print(best_prop)
    if best_prop > prev:
            a = best_offset - (.5/edge) * best_offset
            b = best_offset + (.5/edge) * best_offset
            c = best_slope + (.5 / slope_edge) * best_slope
            d = best_slope - (.5 / slope_edge) * best_slope
            p, ld, hd, yss, bp, bo, bs = get_best_offset(spectrum,
                                                            slope_range=[c,d],
                                                            offset_range=[a, b],
                                                            prev=best_prop,
                                                            offsets=20,
                                                            slopes=5, 
                                                            first=False, 
                                                            frags=frags)
            if bp >= best_prop:
                proportions = p
                low_distances = ld
                high_distances = hd
                ys = yss
                best_prop = bp
                best_offset = bo
                best_slope = bs
    return (proportions, low_distances, high_distances, ys, best_prop,
            best_offset, best_slope)

# %%
offsets = []
slopes = []
files = []
indices = []
i = 0
for row in df.loc[478:956].itertuples():
    print(i)
    a, b, c, d, p, o, s = get_best_offset(row, [.001, .0000001],
                                          [.001, .000001], offsets=20,
                                          slopes=20,
                                          prev=0,
                                          frags=spots)
    offsets.append(o)
    slopes.append(s)
    files.append(row.file_name)
    indices.append(row.index)
    i += 1
# Out:
# 0
# optimizing S13A8-U1.cas
# initial proportion: 0.25925925925925924
# 0.4074074074074074
# 0.4074074074074074
# 1
# optimizing S13A8-V1.cas
# initial proportion: 0.047619047619047616
# 0.2857142857142857
# 0.2857142857142857
# 2
# optimizing S13A9-U1.cas
# initial proportion: 0.34558823529411764
# 0.45588235294117646
# 0.47058823529411764
# 0.47058823529411764
# 3
# optimizing S13A9-V1.cas
# initial proportion: 0.18604651162790697
# 0.2558139534883721
# 0.3488372093023256
# 0.3488372093023256
# 4
# optimizing S13B0-U1.cas
# initial proportion: 0.9230769230769231
# 0.9487179487179487
# 0.9487179487179487
# 5
# optimizing S13B1-U1.cas
# initial proportion: 0.39814814814814814
# 0.4074074074074074
# 0.4537037037037037
# 0.4537037037037037
# 6
# optimizing S13B0-V1.cas
# initial proportion: 0.9230769230769231
# 1.0
# 1.0
# 7
# optimizing S13B1-V1.cas
# initial proportion: 0.1875
# 0.1875
# 0.1875
# 8
# optimizing S13B4-U1.cas
# initial proportion: 0.75
# 0.7564102564102564
# 0.7756410256410257
# 0.7756410256410257
# 9
# optimizing S13B6-U1.cas
# initial proportion: 0.4146341463414634
# 0.45121951219512196
# 0.45121951219512196
# 10
# optimizing S13B4-V1.cas
# initial proportion: 0.7
# 0.7666666666666667
# 0.7666666666666667
# optimizing S1555-U1.cas
# initial proportion: 0.13333333333333333
# 0.6444444444444445
# 0.6444444444444445
# 162
# optimizing S1556-U1.cas
# initial proportion: 0.0875
# 0.65
# 0.6375
# 163
# optimizing S1557-U1.cas
# initial proportion: 0.6040268456375839
# 0.6308724832214765
# 0.6241610738255033
# 164
# optimizing S1556-V1.cas
# initial proportion: 0.6956521739130435
# 0.7391304347826086
# 0.8695652173913043
# 0.8695652173913043
# 165
# optimizing S1557-V1.cas
# initial proportion: 0.22
# 0.6
# 0.6
# 166
# optimizing S1558-U1.cas
# initial proportion: 0.5348837209302325
# 0.627906976744186
# 0.6976744186046512
# 0.6976744186046512
# 167
# optimizing S1558-V1.cas
# initial proportion: 0.7222222222222222
# 0.7222222222222222
# 0.7222222222222222
# 168
# optimizing S1559-V1.cas
# initial proportion: 0.6290322580645161
# 0.6774193548387096
# 0.6774193548387096
# 169
# optimizing S1559-U1.cas
# initial proportion: 0.5339805825242718
# 0.6666666666666666
# 0.6666666666666666
# 170
# optimizing S1560-V1.cas
# initial proportion: 0.22916666666666666
# 0.6875
# 0.6875
# 171
# optimizing S1560-U1.cas
# initial proportion: 0.578125
# 0.6614173228346457
# 0.6929133858267716
# 0.6850393700787402
# 172
# optimizing S1561-V1.cas
# initial proportion: 0.4772727272727273
# 0.5681818181818182
# 0.5681818181818182
# 173
# optimizing S1561-U1.cas
# initial proportion: 0.5142857142857142
# 0.7142857142857143
# 0.7142857142857143
# 174
# optimizing S1562-U1.cas
# initial proportion: 0.0
# 0.6119402985074627
# 0.6268656716417911
# 0.6119402985074627
# 175
# optimizing S1563-U1.cas
# initial proportion: 0.4583333333333333
# 0.6956521739130435
# 0.6956521739130435
# 176
# optimizing S1562-V1.cas
# initial proportion: 0.08823529411764706
# 0.6764705882352942
# 0.6764705882352942
# 177
# optimizing S1563-V1.cas
# initial proportion: 0.3125
# 0.7741935483870968
# 0.7741935483870968
# 178
# optimizing S1564-U1.cas
# initial proportion: 0.5131578947368421
# 0.5575221238938053
# 0.5663716814159292
# 0.5530973451327433
# 179
# optimizing S1564-V1.cas
# initial proportion: 0.5319148936170213
# 0.7391304347826086
# 0.7391304347826086
# 180
# optimizing S1566-V1.cas
# initial proportion: 0.2048780487804878
# 0.56
# 0.56
# 181
# optimizing S1566-U1.cas
# initial proportion: 0.22972972972972974
# 0.2777777777777778
# 0.2777777777777778
# 182
# optimizing S1567-U1.cas
# initial proportion: 0.475
# 0.585
# 0.625
# 0.655
# 0.655
# 183
# optimizing S1567-V1.cas
# initial proportion: 0.6434108527131783
# 0.7131782945736435
# 0.751937984496124
# 0.7364341085271318
# 184
# optimizing S1568-U1.cas
# initial proportion: 0.4098939929328622
# 0.4169611307420495
# 0.4169611307420495
# 185
# optimizing S1601-U1.cas
# initial proportion: 0.3819444444444444
# 0.5848214285714286
# 0.5892857142857143
# 0.5892857142857143
# 186
# optimizing S1568-V1.cas
# initial proportion: 0.40293040293040294
# 0.5370370370370371
# 0.5407407407407407
# optimizing S1728-U1.cas
# initial proportion: 0.2737341772151899
# 0.3632887189292543
# 0.37858508604206503
# 0.37476099426386233
# 237
# optimizing S1727-V1.cas
# initial proportion: 0.5428571428571428
# 0.5428571428571428
# 0.5428571428571428
# 238
# optimizing S1729-U1.cas
# initial proportion: 0.5828220858895705
# 0.6428571428571429
# 0.6428571428571429
# 239
# optimizing S1728-V1.cas
# initial proportion: 0.3403141361256545
# 0.48404255319148937
# 0.4095744680851064
# 240
# optimizing S1729-V1.cas
# initial proportion: 0.4444444444444444
# 0.6111111111111112
# 0.6111111111111112
# 241
# optimizing S1730-U1.cas
# initial proportion: 0.4810810810810811
# 0.627906976744186
# 0.6395348837209303
# 0.627906976744186
# 242
# optimizing S1730-V1.cas
# initial proportion: 0.398989898989899
# 0.5353535353535354
# 0.5404040404040404
# 0.5404040404040404
# 243
# optimizing S1731-U1.cas
# initial proportion: 0.3780718336483932
# 0.5059952038369304
# 0.5347721822541966
# 0.5371702637889688
# 0.5347721822541966
# 244
# optimizing S1732-U1.cas
# initial proportion: 0.37155963302752293
# 0.47572815533980584
# 0.48058252427184467
# 0.47572815533980584
# 245
# optimizing S1731-V1.cas
# initial proportion: 0.6341463414634146
# 0.6865671641791045
# 0.7064676616915423
# 0.6965174129353234
# 246
# optimizing S1733-U1.cas
# initial proportion: 0.4142857142857143
# 0.44713656387665196
# 0.44713656387665196
# 247
# optimizing S1732-V1.cas
# initial proportion: 0.5722222222222222
# 0.5833333333333334
# 0.5888888888888889
# 0.6
# 0.6055555555555555
# 0.6055555555555555
# 248
# optimizing S1733-V1.cas
# initial proportion: 0.543010752688172
# 0.6
# 0.6216216216216216
# 0.6270270270270271
# 0.6270270270270271
# 249
# optimizing S1734-U1.cas
# initial proportion: 0.41421568627450983
# 0.5251989389920424
# 0.5384615384615384
# 0.5384615384615384
# 250
# optimizing S1734-V1.cas
# initial proportion: 0.4301675977653631
# 0.6127167630057804
# 0.6127167630057804
# 251
# optimizing S1735-U1.cas
# initial proportion: 0.46107784431137727
# 0.5555555555555556
# 0.5620915032679739
# 0.565359477124183
# 0.565359477124183
# 252
# optimizing S1735-V1.cas
# initial proportion: 0.5606060606060606
# 0.7622950819672131
# 0.7704918032786885
# 0.7622950819672131
# 253
# optimizing S1736-U1.cas
# initial proportion: 0.5045871559633027
# 0.5860927152317881
# 0.5960264900662252
# 0.5860927152317881
# 254
# optimizing S1737-U1.cas
# initial proportion: 0.412568306010929
# 0.5756676557863502
# 0.5905044510385756
# 0.5934718100890207
# 0.5964391691394659
# 0.5964391691394659
# 255
# optimizing S1736-V1.cas
# initial proportion: 0.49261083743842365
# 0.8081395348837209
# 0.8081395348837209
# 256
# optimizing S1737-V1.cas
# initial proportion: 0.5
# 0.7150259067357513
# 0.7564766839378239
# 0.7564766839378239
# 257
# optimizing S1738-V1.cas
# initial proportion: 0.254
# 0.4226044226044226
# 0.4201474201474201
# 258
# optimizing S1738-U1.cas
# initial proportion: 0.11946591707659873
# 0.2726008344923505
# 0.6103896103896104
# 333
# optimizing S2110-U1.cas
# initial proportion: 0.6666666666666666
# 0.6944444444444444
# 0.6944444444444444
# 334
# optimizing S2105-V1.cas
# initial proportion: 0.7288135593220338
# 0.7457627118644068
# 0.7457627118644068
# 335
# optimizing S2110-V1.cas
# initial proportion: 0.8333333333333334
# 0.8333333333333334
# 0.8333333333333334
# 336
# optimizing S2111-U1.cas
# initial proportion: 0.37662337662337664
# 0.5974025974025974
# 0.6103896103896104
# 0.5194805194805194
# 337
# optimizing S2111-V1.cas
# initial proportion: 0.4492753623188406
# 0.48484848484848486
# 0.48484848484848486
# 338
# optimizing S2112-U1.cas
# initial proportion: 0.5117647058823529
# 0.5470588235294118
# 0.5470588235294118
# 339
# optimizing S2112-V1.cas
# initial proportion: 0.5510204081632653
# 0.5816326530612245
# 0.5816326530612245
# 340
# optimizing S2201-U1.cas
# initial proportion: 0.7391304347826086
# 0.8059701492537313
# 0.7910447761194029
# 341
# optimizing S2201-V1.cas
# initial proportion: 0.581081081081081
# 0.6486486486486487
# 0.6216216216216216
# 342
# optimizing S2202-U1.cas
# initial proportion: 0.5977011494252874
# 0.6904761904761905
# 0.7023809523809523
# 0.7023809523809523
# 343
# optimizing S2302-U1.cas
# initial proportion: 0.42857142857142855
# 0.5
# 0.4857142857142857
# 344
# optimizing S2202-V1.cas
# initial proportion: 0.6666666666666666
# 0.7575757575757576
# 0.7575757575757576
# 345
# optimizing S2302-V1.cas
# initial proportion: 0.47058823529411764
# 0.47058823529411764
# 0.47058823529411764
# 346
# optimizing S2305-U1.cas
# initial proportion: 0.2631578947368421
# 0.631578947368421
# 0.631578947368421
# 347
# optimizing S2305-V1.cas
# initial proportion: 0.3333333333333333
# 0.8
# 0.8
# 348
# optimizing S2306-U1.cas
# initial proportion: 0.2967032967032967
# 0.43956043956043955
# 0.45054945054945056
# 0.43956043956043955
# 349
# optimizing S2306-V1.cas
# initial proportion: 0.4358974358974359
# 0.5641025641025641
# 0.5641025641025641
# 350
# optimizing S2308-U1.cas
# initial proportion: 0.37209302325581395
# 0.627906976744186
# 0.6511627906976745
# 0.6046511627906976
# 351
# optimizing S2308-V1.cas
# initial proportion: 0.4827586206896552
# 0.6896551724137931
# 0.7241379310344828
# 0.7241379310344828
# 352
# optimizing S2309-U1.cas
# initial proportion: 0.5974842767295597
# 0.6226415094339622
# 0.6352201257861635
# 0.6352201257861635
# 353
# optimizing S2310-U1.cas
# initial proportion: 0.6551724137931034
# 0.6896551724137931
# 0.6896551724137931
# 354
# optimizing S2309-V1.cas
# initial proportion: 0.5529411764705883
# 0.5764705882352941
# 0.5882352941176471
# 0.5882352941176471
# 355
# optimizing S2310-V1.cas
# initial proportion: 0.6122448979591837
# 0.6122448979591837
# 0.6122448979591837
# 356
# optimizing S2311-U1.cas
# initial proportion: 0.49673202614379086
# 0.5294117647058824
# 0.5294117647058824
# 357
# optimizing S2311-V1.cas
# initial proportion: 0.6923076923076923
# 0.7307692307692307
# 0.7307692307692307
# 358
# optimizing S2313-U1.cas
# initial proportion: 0.2727272727272727
# 0.5227272727272727
# 0.5227272727272727
# 359
# optimizing S2313-V1.cas
# initial proportion: 0.38333333333333336
# 0.5666666666666667
# 0.5833333333333334
# 0.5833333333333334
# 360
# optimizing S2316-U1.cas
# initial proportion: 0.17419354838709677
# 0.4155844155844156
# 0.42207792207792205
# 0.4090909090909091
# 361
# optimizing S2316-V1.cas
# initial proportion: 0.01107011070110701
# 0.10566037735849057
# 0.27547169811320754
# 0.30566037735849055
# 0.2981132075471698
# 362
# optimizing S2317-U1.cas
# initial proportion: 0.375
# 0.4845360824742268
# 0.4742268041237113
# 363
# optimizing S2401-U1.cas
# initial proportion: 0.25252525252525254
# 0.43434343434343436
# 0.4444444444444444
# 0.4444444444444444
# 364
# optimizing S2317-V1.cas
# initial proportion: 0.411214953271028
# 0.5327102803738317
# 0.514018691588785
# 365
# optimizing S2401-V1.cas
# initial proportion: 0.5161290322580645
# 0.5806451612903226
# 0.5806451612903226
# 366
# optimizing S2402-U1.cas
# initial proportion: 0.13953488372093023
# 0.5581395348837209
# 0.5348837209302325
# 367
# optimizing S2402-V1.cas
# initial proportion: 0.25
# 0.5416666666666666
# 0.5833333333333334
# 0.5833333333333334
# 368
# optimizing S2403-U1.cas
# initial proportion: 0.2777777777777778
# 0.5277777777777778
# 0.5277777777777778
# 369
# optimizing S2403-V1.cas
# initial proportion: 0.1
# 0.65
# 0.65
# 370
# optimizing S2404-U1.cas
# initial proportion: 0.4090909090909091
# 0.6363636363636364
# 0.6363636363636364
# 371
# optimizing S2404-V1.cas
# initial proportion: 0.37209302325581395
# 0.627906976744186
# 0.6511627906976745
# 0.6046511627906976
# 372
# optimizing S2405-U1.cas
# initial proportion: 0.13333333333333333
# 0.5333333333333333
# 0.5666666666666667
# 0.6
# 0.5666666666666667
# 373
# optimizing S2405-V1.cas
# initial proportion: 0.4444444444444444
# 0.7407407407407407
# 0.7407407407407407
# 374
# optimizing S2406-U1.cas
# initial proportion: 0.3181818181818182
# 0.8181818181818182
# 0.8181818181818182
# 375
# optimizing S2406-V1.cas
# initial proportion: 0.5769230769230769
# 0.6538461538461539
# 0.6538461538461539
# 376
# optimizing S2407-U1.cas
# initial proportion: 0.0625
# 0.71875
# 0.71875
# 377
# optimizing S2407-V1.cas
# initial proportion: 0.25
# 0.7142857142857143
# 0.7142857142857143
# 378
# optimizing S2408-U1.cas
# initial proportion: 0.3090909090909091
# 0.4
# 0.41818181818181815
# 0.4
# 379
# optimizing S2408-V1.cas
# initial proportion: 0.26666666666666666
# 0.6
# 0.6
# 380
# optimizing S2409-U1.cas
# initial proportion: 0.29508196721311475
# 0.5409836065573771
# 0.5409836065573771
# 381
# optimizing S2410-U1.cas
# initial proportion: 0.07936507936507936
# 0.38095238095238093
# 0.38095238095238093
# 382
# optimizing S2409-V1.cas
# initial proportion: 0.022222222222222223
# 0.08888888888888889
# 0.4
# 0.4444444444444444
# 0.5555555555555556
# 0.5333333333333333
# 0.6666666666666666
# 0.6666666666666666
# 434
# optimizing S3219-U1.cas
# initial proportion: 0.2857142857142857
# 0.4603174603174603
# 0.4444444444444444
# 435
# optimizing S3219-V1.cas
# initial proportion: 0.30303030303030304
# 0.6060606060606061
# 0.6060606060606061
# 436
# optimizing S3220-U1.cas
# initial proportion: 0.2777777777777778
# 0.5
# 0.48148148148148145
# 437
# optimizing S3220-V1.cas
# initial proportion: 0.16
# 0.6
# 0.6
# 438
# optimizing S3221-U1.cas
# initial proportion: 0.15384615384615385
# 0.40384615384615385
# 0.40384615384615385
# 439
# optimizing S3221-V1.cas
# initial proportion: 0.3548387096774194
# 0.6451612903225806
# 0.6451612903225806
# 440
# optimizing S3223-U1.cas
# initial proportion: 0.3484848484848485
# 0.45454545454545453
# 0.45454545454545453
# 441
# optimizing S3223-V1.cas
# initial proportion: 0.24242424242424243
# 0.6666666666666666
# 0.6666666666666666
# 442
# optimizing S3224-U1.cas
# initial proportion: 0.3508771929824561
# 0.40350877192982454
# 0.40350877192982454
# 443
# optimizing S3224-V1.cas
# initial proportion: 0.16666666666666666
# 0.75
# 0.75
# 444
# optimizing S3226-U1.cas
# initial proportion: 0.2692307692307692
# 0.5192307692307693
# 0.5576923076923077
# 0.5384615384615384
# 445
# optimizing S3226-V1.cas
# initial proportion: 0.2
# 0.6666666666666666
# 0.6666666666666666
# 446
# optimizing S3227-U1.cas
# initial proportion: 0.19117647058823528
# 0.5
# 0.45588235294117646
# 447
# optimizing S3227-V1.cas
# initial proportion: 0.0
# 0.4788732394366197
# 0.4788732394366197
# 448
# optimizing S3228-U1.cas
# initial proportion: 0.3275862068965517
# 0.39655172413793105
# 0.39655172413793105
# 449
# optimizing S3228-V1.cas
# initial proportion: 0.14285714285714285
# 0.6666666666666666
# 0.6666666666666666
# 450
# optimizing S3229-U1.cas
# initial proportion: 0.18181818181818182
# 0.4935064935064935
# 0.4935064935064935
# 451
# optimizing S3229-V1.cas
# initial proportion: 0.19230769230769232
# 0.6153846153846154
# 0.6538461538461539
# 0.6153846153846154
# 452
# optimizing S3230-U1.cas
# initial proportion: 0.21428571428571427
# 0.5119047619047619
# 0.5119047619047619
# 453
# optimizing S3230-V1.cas
# initial proportion: 0.27450980392156865
# 0.5882352941176471
# 0.5882352941176471
# 454
# optimizing S3231-U1.cas
# initial proportion: 0.10256410256410256
# 0.5641025641025641
# 0.5641025641025641
# 455
# optimizing S3231-V1.cas
# initial proportion: 0.19696969696969696
# 0.6515151515151515
# 0.6363636363636364
# 456
# optimizing S3232-U1.cas
# initial proportion: 0.10101010101010101
# 0.15151515151515152
# 0.15151515151515152
# 457
# optimizing S3232-V1.cas
# initial proportion: 0.3076923076923077
# 0.75
# 0.75
# 458
# optimizing S3233-U1.cas
# initial proportion: 0.15625
# 0.484375
# 0.484375
# 459
# optimizing S3233-V1.cas
# initial proportion: 0.2727272727272727
# 0.7727272727272727
# 0.7727272727272727
# 460
# optimizing S3234-U1.cas
# initial proportion: 0.19148936170212766
# 0.5106382978723404
# 0.5106382978723404
# 461
# optimizing S3234-V1.cas
# initial proportion: 0.11904761904761904
# 0.6428571428571429
# 0.6666666666666666
# 0.6428571428571429
# 462
# optimizing S3235-U1.cas
# initial proportion: 0.14285714285714285
# 0.6111111111111112
# 0.6031746031746031
# 463
# optimizing S3235-V1.cas
# initial proportion: 0.171875
# 0.65625
# 0.65625
# 464
# optimizing S3236-U1.cas
# initial proportion: 0.2289156626506024
# 0.5783132530120482
# 0.5783132530120482
# 465
# optimizing S3236-V1.cas
# initial proportion: 0.1956521739130435
# 0.6521739130434783
# 0.6521739130434783
# 466
# optimizing S3237-U1.cas
# initial proportion: 0.10112359550561797
# 0.5168539325842697
# 0.5056179775280899
# 467
# optimizing S3237-V1.cas
# initial proportion: 0.125
# 0.5
# 0.5
# 468
# optimizing S3238-U1.cas
# initial proportion: 0.205607476635514
# 0.514018691588785
# 0.514018691588785
# 469
# optimizing S3238-V1.cas
# initial proportion: 0.24489795918367346
# 0.5714285714285714
# 0.5714285714285714
# 470
# optimizing S3318-U1.cas
# initial proportion: 0.39215686274509803
# 0.6666666666666666
# 0.6666666666666666
# 471
# optimizing S3318-V1.cas
# initial proportion: 0.2692307692307692
# 0.7692307692307693
# 0.7692307692307693
# 472
# optimizing S3319-U1.cas
# initial proportion: 0.375
# 0.6666666666666666
# 0.7083333333333334
# 0.6875
# 473
# optimizing S3319-V1.cas
# initial proportion: 0.25925925925925924
# 0.6666666666666666
# 0.6666666666666666
# 474
# optimizing S3320-U1.cas
# initial proportion: 0.5735294117647058
# 0.7058823529411765
# 0.7058823529411765
# 475
# optimizing S3320-V1.cas
# initial proportion: 0.2413793103448276
# 0.6551724137931034
# 0.6551724137931034
# 476
# optimizing S3321-U1.cas
# initial proportion: 0.15714285714285714
# 0.7
# 0.7
# 477
# optimizing S3321-V1.cas
# initial proportion: 0.22580645161290322
# 0.7419354838709677
# 0.7419354838709677
# 478
# optimizing S3325-U1.cas
# initial proportion: 0.1865671641791045
# 0.319672131147541
# 0.32786885245901637
# 0.32786885245901637

# %%
pd.DataFrame({'offsets':offsets, 'slopes':slopes, 'names':files, 'indices':indices}).to_csv('../data/updated_calibration_new_1900_first_478_956.csv', index=False)

# %%
pd.read_csv('../data/updated_calibration_new_1900_first_478_956.csv')
# Out:
#       offsets        slopes         names  indices
# 0    0.000495 -1.053526e-04  S13A8-U1.cas      479
# 1    0.000495 -1.000000e-03  S13A8-V1.cas      480
# 2    0.000245 -1.935903e-04  S13A9-U1.cas      481
# 3    0.000245  1.795446e-04  S13A9-V1.cas      482
# 4    0.000052  4.505495e-08  S13B0-U1.cas      483
# ..        ...           ...           ...      ...
# 474 -0.000415 -4.505495e-08  S3320-U1.cas      953
# 475 -0.000244  2.632316e-04  S3320-V1.cas      954
# 476  0.000624  3.158579e-04  S3321-U1.cas      955
# 477  0.000110  3.684842e-04  S3321-V1.cas      956
# 478  0.001385  4.737368e-04  S3325-U1.cas      957
#
# [479 rows x 4 columns]
