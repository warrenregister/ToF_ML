# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sys import path
# %matplotlib inline

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# %cd /content/drive/MyDrive/PHI/ToF_ML/src
# Out:
# /content/drive/MyDrive/PHI/ToF_ML/src

# %%
from data_transformation import get_frags
spots = get_frags()['FragmentMass']

# %%
def C(channels, spec_bin_size, start_time,  mass_over_time, mass_offset):
    return ((np.array(channels) * .001 * spec_bin_size + start_time) * mass_over_time + mass_offset)**2

# %%
df_read = pd.read_csv('../data/ssl_csvs_converted_to_df.csv')
from ast import literal_eval
df_read['intensities'] = df_read['intensities'].apply(literal_eval)
df_read['channels'] = df_read['channels'].apply(literal_eval)

# %%
df_read.head()
# Out:
#       file_name  ...                                           channels
# 0  C0059-V1.cas  ...  [12729.6134, 13388.07292, 14021.38724, 14625.2...
# 1  C0060-V1.cas  ...  [12773.45818, 13433.49441, 13495.05187, 14068....
# 2  C0061-U1.cas  ...  [12779.34033, 13440.22492, 14076.03163, 14689....
# 3  C0061-V1.cas  ...  [1381.98178, 1400.517, 1412.53457, 1440.11759,...
# 4  C0062-U1.cas  ...  [12795.06881, 13456.57005, 14092.96684, 14707....
#
# [5 rows x 8 columns]

# %%
from data_transformation import mass_formula
def generate_calibrated_data(data, numba=False):
    '''
    Applies mass_formula to every row in dataset to allow
    calibrated graphs to be generated.
    '''
    new_data = data.copy()
    masses = []
    for row in new_data.itertuples():
        spec = row.SpecBinSize
        m_over_t = row.MassOverTime
        m_offset = row.MassOffset
        time = row.StartFlightTime
        if not numba:
            masses.append(mass_formula(np.array(row.channels), spec, time,
                          m_over_t, m_offset))
        else:
            masses.append(numba_mass_formula(np.array(row.channels), spec,
                          time, m_over_t, m_offset))
    new_data['masses'] = masses
    return new_data

# %%
from data_transformation import get_fragment_stats, generate_calibrated_data
df_read = generate_calibrated_data(df_read[df_read['channels'].apply(len)> 0])
df_read.reset_index(inplace=True)

# %%
df_read.head()
# Out:
#    index  ...                                             masses
# 0      0  ...  [12.004495885110552, 13.012398275521816, 14.02...
# 1      1  ...  [12.004681147019333, 13.01242014410188, 13.108...
# 2      2  ...  [12.003062954788383, 13.010939902638805, 14.01...
# 3      3  ...  [1.016159799036636, 1.024261311539043, 1.02953...
# 4      4  ...  [12.002858579352937, 13.010660285835183, 14.01...
#
# [5 rows x 10 columns]

# %%
df = get_fragment_stats(df_read, prop_name='proportions_peaks_identified')

# %%
df.to_csv('../data/new_1900_without_peakless_spectra.csv', index=False)

# %%
a = df['index']
df.drop('index', axis=1, inplace=True)
df['index'] = a

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   file_name                              1911 non-null   object
#  1   technique                              1911 non-null   object
#  2   StartFlightTime                        1911 non-null   float64
#  3   MassOverTime                           1911 non-null   float64
#  4   MassOffset                             1911 non-null   float64
#  5   SpecBinSize                            1911 non-null   float64
#  6   intensities                            1911 non-null   object
#  7   channels                               1911 non-null   object
#  8   masses                                 1911 non-null   object
#  9   avg_dist_frags_low                     1911 non-null   float64
#  10  avg_dist_frags_high                    1911 non-null   float64
#  11  adjusted_proportions_peaks_identified  1911 non-null   float64
#  12  proportions_peaks_identified           1911 non-null   float64
#  13  diff                                   1911 non-null   float64
#  14  prop_diff_in_low                       1900 non-null   float64
#  15  calibration                            1911 non-null   int64
#  16  index                                  1911 non-null   int64
# dtypes: float64(10), int64(2), object(5)
# memory usage: 253.9+ KB

# %%
df.head()
# Out:
#       file_name  technique  ...  calibration  index
# 0  C0059-V1.cas   -TofSIMS  ...            0      0
# 1  C0060-V1.cas   -TofSIMS  ...            0      1
# 2  C0061-U1.cas   +TofSIMS  ...            0      2
# 3  C0061-V1.cas   -TofSIMS  ...            0      3
# 4  C0062-U1.cas   +TofSIMS  ...            0      4
#
# [5 rows x 17 columns]

# %%
def recalibrate(row, spots, slope_amt=0, offset_amt=0, num_peaks=False):
    '''
    Function which quickly asseses the calibration of a spectrum.
    '''
    slope = row.MassOverTime + slope_amt *  row.MassOverTime
    offset = row.MassOffset + offset_amt * row.MassOffset
    peaks = []
    peaks = mass_formula(np.array(row.channels), row.SpecBinSize, row.StartFlightTime, slope,
                   offset)
    masses, frags1, dist1, masses2, frags2, dist2 = get_frags_dists(peaks,
                                                                    spots,
                                                                    [.003,.007])
    prop = len(masses) / len(peaks[peaks<336])
    low_dist = 0
    high_dist = 0
    if len(dist1) > 0:
        low_dist = np.mean(dist1)
    if len(dist2) > 0:
        high_dist = np.mean(dist2)
    if num_peaks:
        return prop, low_dist, high_dist, len(masses)
    else:
        return prop, low_dist, high_dist

# %%
from data_transformation import get_frags_dists

# %%
def get_best_offset(spectrum, slope_range, offset_range, prev=0,
                    offsets=30, slopes=20, first=True, frags=None):
    '''
    Find best amount of slope/offset to add/subtract to slope/offset value
    to achieve the optimal calibration for spectrum. Calibration is measured
    using mass fragments. A spectrum which more matches to known masses is more
    calibrated than one with fewer. A spectrum whose matches are very close to
    known mass is more calibrated than one that is further away.

    Arguments -------
    spectrum: row from dataframe containing information on a spectrum
    slope_range: data structure containing min, max slope to try, slope erros
                 are typically smaller than offset errors.
    offset_range: data structure containing min, max offset agumentation
                       to try. This method shrinks the range iteratively until
                       the best offset is achieved.
    spots: a list of mass fragments
    '''
    if first:
        print('optimizing ' + spectrum.file_name)
        print('initial proportion: ' + str(spectrum.proportions_peaks_identified))
    if not isinstance(frags, pd.Series):
        frags = get_frags()
    proportions = [0]
    low_distances = []
    high_distances = []
    best_prop = 0
    best_offset = spectrum.MassOffset
    best_slope = spectrum[2]
    best_ld = 1
    best_hd = 1
    ys = [] 
    i = 0
    mults = [1, -1]
    slope_space = np.linspace(slope_range[0], slope_range[1], slopes)
    while 1:
        slope = slope_space[i]
        for slope_mult in mults:
            slope_val = slope * slope_mult
            props = []
            low_dists = []
            high_dists = []
            y = []
            space = np.linspace(offset_range[0], offset_range[1], offsets)
            j = 0
            changed = False
            while 1:
                offset = space[j]
                for mult in mults:
                    improved = False
                    val = mult * offset
                    y.append(val)
                    prop, low, high = recalibrate(spectrum, frags, slope_val, val)
                    if prop > best_prop:
                        improved=True
                    elif (prop == best_prop and best_hd - high > 0 and
                          best_ld - low > 0):
                        improved = True
                    props.append(prop)
                    low_dists.append(low)
                    high_dists.append(high)
                    if improved:
                        best_prop = prop 
                        best_offset = val
                        best_slope = slope_val
                        best_ld = low
                        best_hd = high
                        edge = (np.where(space == mult * best_offset)[0][0] + .1)/ len(space)
                        edge = 2 * abs(.5 - edge)
                        slope_edge = np.where(slope_space == slope_mult * best_slope)[0][0]
                        slope_edge = 2 * abs(.5 - (slope_edge + .1) / len(slope_space))
                        changed = True            
                j += 1
                if j >= len(space):
                    break
            if changed:
                ys = y 
                proportions = props 
                low_distances = low_dists
                high_distances = high_dists
        i += 1
        if i >= len(slope_space):
            break
    print(best_prop)
    if best_prop > prev:
            a = best_offset - (.5/edge) * best_offset
            b = best_offset + (.5/edge) * best_offset
            c = best_slope + (.5 / slope_edge) * best_slope
            d = best_slope - (.5 / slope_edge) * best_slope
            p, ld, hd, yss, bp, bo, bs = get_best_offset(spectrum,
                                                            slope_range=[c,d],
                                                            offset_range=[a, b],
                                                            prev=best_prop,
                                                            offsets=20,
                                                            slopes=5, 
                                                            first=False, 
                                                            frags=frags)
            if bp >= best_prop:
                proportions = p
                low_distances = ld
                high_distances = hd
                ys = yss
                best_prop = bp
                best_offset = bo
                best_slope = bs
    return (proportions, low_distances, high_distances, ys, best_prop,
            best_offset, best_slope)

# %%
offsets = []
slopes = []
files = []
indices = []
i = 0
for row in df.loc[1434:].itertuples():
    print(i)
    a, b, c, d, p, o, s = get_best_offset(row, [.001, .0000001],
                                          [.001, .000001], offsets=20,
                                          slopes=20,
                                          prev=0,
                                          frags=spots)
    offsets.append(o)
    slopes.append(s)
    files.append(row.file_name)
    indices.append(row.index)
    i += 1
# Out:
# 0
# optimizing B1750-U1.cas
# initial proportion: 0.6093023255813953
# 0.7005347593582888
# 0.7005347593582888
# 1
# optimizing B1749-V1.cas
# initial proportion: 0.6521739130434783
# 0.6521739130434783
# 0.6521739130434783
# 2
# optimizing B1750-V1.cas
# initial proportion: 0.6510067114093959
# 0.697841726618705
# 0.697841726618705
# 3
# optimizing B1751-U1.cas
# initial proportion: 0.5204359673024523
# 0.5993690851735016
# 0.6025236593059937
# 0.6056782334384858
# 0.6056782334384858
# 4
# optimizing B1751-V1.cas
# initial proportion: 0.64
# 0.6906474820143885
# 0.6906474820143885
# 5
# optimizing B1752-V1.cas
# initial proportion: 0.5298507462686567
# 0.6859504132231405
# 0.7851239669421488
# 0.7851239669421488
# 6
# optimizing B1752-U1.cas
# initial proportion: 0.5209125475285171
# 0.6160714285714286
# 0.6160714285714286
# 7
# optimizing B1753-U1.cas
# initial proportion: 0.6050955414012739
# 0.6418918918918919
# 0.6452702702702703
# 0.6486486486486487
# 0.6486486486486487
# 8
# optimizing B1753-V1.cas
# initial proportion: 0.6926229508196722
# 0.6954732510288066
# 0.6954732510288066
# 9
# optimizing B1754-U1.cas
# initial proportion: 0.486646884272997
# 0.543046357615894
# 0.5463576158940397
# 0.5463576158940397
# 10
# optimizing B1754-V1.cas
# initial proportion: 0.5579710144927537
# 0.6746031746031746
# 0.7222222222222222
# 0.7301587301587301
# 0.7380952380952381
# 0.7380952380952381
# 11
# optimizing B1755-V1.cas
# optimizing B1953-U1.cas
# initial proportion: 0.15625
# 0.78125
# 0.78125
# 62
# optimizing B1953-V1.cas
# initial proportion: 0.24242424242424243
# 0.6666666666666666
# 0.6666666666666666
# 63
# optimizing B1954-U1.cas
# initial proportion: 0.56
# 0.8
# 0.8
# 64
# optimizing B1954-V1.cas
# initial proportion: 0.20588235294117646
# 0.6764705882352942
# 0.7058823529411765
# 0.7058823529411765
# 65
# optimizing B1955-U1.cas
# initial proportion: 0.2857142857142857
# 0.8214285714285714
# 0.8214285714285714
# 66
# optimizing B1955-V1.cas
# initial proportion: 0.225
# 0.725
# 0.725
# 67
# optimizing B1956-U1.cas
# initial proportion: 0.6288659793814433
# 0.7252747252747253
# 0.7362637362637363
# 0.6153846153846154
# 68
# optimizing B1956-V1.cas
# initial proportion: 0.6818181818181818
# 0.7272727272727273
# 0.7272727272727273
# 69
# optimizing B1957-U1.cas
# initial proportion: 0.4351464435146444
# 0.4745762711864407
# 0.4830508474576271
# 0.4745762711864407
# 70
# optimizing B1958-U1.cas
# initial proportion: 0.5273972602739726
# 0.5616438356164384
# 0.821917808219178
# 0.821917808219178
# 71
# optimizing B1957-V1.cas
# initial proportion: 0.11188811188811189
# 0.5454545454545454
# 0.5454545454545454
# 72
# optimizing B1958-V1.cas
# initial proportion: 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 73
# optimizing B1959-U1.cas
# initial proportion: 0.6717948717948717
# 0.6717948717948717
# 0.676923076923077
# 0.676923076923077
# 74
# optimizing B1959-V1.cas
# initial proportion: 0.4696969696969697
# 0.4696969696969697
# 0.4696969696969697
# 75
# optimizing B1960-U1.cas
# initial proportion: 0.5955056179775281
# 0.5955056179775281
# 0.5955056179775281
# 76
# optimizing B1960-V1.cas
# initial proportion: 0.3888888888888889
# 0.3888888888888889
# 0.3888888888888889
# 77
# optimizing B1961-U1.cas
# initial proportion: 0.7668393782383419
# 0.7668393782383419
# 0.7772020725388601
# 0.7772020725388601
# 78
# optimizing B1961-V1.cas
# initial proportion: 0.28368794326241137
# 0.28368794326241137
# 0.28368794326241137
# 79
# optimizing B1962-U1.cas
# initial proportion: 0.4827586206896552
# 0.6896551724137931
# 0.7241379310344828
# 0.7471264367816092
# 0.7471264367816092
# 80
# optimizing B1962-V1.cas
# initial proportion: 0.53125
# 0.8125
# 0.8125
# 81
# optimizing B1963-U1.cas
# initial proportion: 0.7066115702479339
# 0.7066115702479339
# 0.7066115702479339
# 82
# optimizing B1963-V1.cas
# initial proportion: 0.375
# 0.37894736842105264
# 0.37894736842105264
# 83
# optimizing B1964-V1.cas
# initial proportion: 0.07303370786516854
# 0.484
# 0.488
# 0.476
# 84
# optimizing B1964-U1.cas
# initial proportion: 0.17027027027027028
# 0.4115853658536585
# 0.40853658536585363
# 85
# optimizing B1965-U1.cas
# initial proportion: 0.5
# 0.5849056603773585
# 0.5754716981132075
# 86
# optimizing B1965-V1.cas
# initial proportion: 0.3548387096774194
# 0.3870967741935484
# 0.3870967741935484
# 87
# optimizing B1966-U1.cas
# initial proportion: 0.20180722891566266
# 0.4057507987220447
# 0.3993610223642173
# 243
# optimizing B3334-V1.cas
# initial proportion: 0.06060606060606061
# 0.4117647058823529
# 0.41830065359477125
# 0.4117647058823529
# 244
# optimizing B3334-U1.cas
# initial proportion: 0.11057692307692307
# 0.49206349206349204
# 0.5079365079365079
# 0.5132275132275133
# 0.4973544973544973
# 245
# optimizing B3335-V1.cas
# initial proportion: 0.07380952380952381
# 0.33488372093023255
# 0.34418604651162793
# 0.34418604651162793
# 246
# optimizing B3335-U1.cas
# initial proportion: 0.18507462686567164
# 0.45901639344262296
# 0.46229508196721314
# 0.30392156862745096
# 247
# optimizing B3336-V1.cas
# initial proportion: 0.07263922518159806
# 0.261455525606469
# 0.2668463611859838
# 0.2560646900269542
# 248
# optimizing B3336-U1.cas
# initial proportion: 0.08425720620842572
# 0.31896551724137934
# 0.31896551724137934
# 249
# optimizing B3337-V1.cas
# initial proportion: 0.07462686567164178
# 0.6363636363636364
# 0.6060606060606061
# 250
# optimizing B3337-U1.cas
# initial proportion: 0.12727272727272726
# 0.6538461538461539
# 0.6538461538461539
# 251
# optimizing B3338-U1.cas
# initial proportion: 0.20689655172413793
# 0.9310344827586207
# 0.9310344827586207
# 252
# optimizing B3339-U1.cas
# initial proportion: 0.46153846153846156
# 0.8461538461538461
# 0.8461538461538461
# 253
# optimizing B3338-V1.cas
# initial proportion: 0.06382978723404255
# 0.5037593984962406
# 0.5112781954887218
# 0.5112781954887218
# 254
# optimizing B3340-U1.cas
# initial proportion: 0.15789473684210525
# 0.7647058823529411
# 0.7647058823529411
# 255
# optimizing B3339-V1.cas
# initial proportion: 0.08571428571428572
# 0.6857142857142857
# 0.6857142857142857
# 256
# optimizing B3340-V1.cas
# initial proportion: 0.625
# 0.6666666666666666
# 0.6666666666666666
# 257
# optimizing B3341-U1.cas
# initial proportion: 0.6829268292682927
# 0.7154471544715447
# 0.7154471544715447
# 258
# optimizing B3341-V1.cas
# initial proportion: 0.8958333333333334
# 0.8958333333333334
# 0.8958333333333334
# 259
# optimizing B3342-U1.cas
# initial proportion: 0.740072202166065
# 0.740072202166065
# 0.740072202166065
# 260
# optimizing B3342-V1.cas
# initial proportion: 0.6593406593406593
# 0.7802197802197802
# 0.7802197802197802
# 261
# optimizing B3343-U1.cas
# initial proportion: 0.5764192139737991
# 0.7336244541484717
# 0.6244541484716157
# 262
# optimizing B3343-V1.cas
# initial proportion: 0.7272727272727273
# 0.8333333333333334
# 0.8333333333333334
# 263
# optimizing B3344-V1.cas
# initial proportion: 0.851063829787234
# 0.851063829787234
# 0.851063829787234
# 264
# optimizing B3344-U1.cas
# initial proportion: 0.5564516129032258
# 0.7258064516129032
# 0.7258064516129032
# 265
# optimizing B3345-U1.cas
# initial proportion: 0.6301369863013698
# 0.7534246575342466
# 0.7602739726027398
# 0.7534246575342466
# 266
# optimizing B3345-V1.cas
# initial proportion: 0.75
# 0.7678571428571429
# 0.7857142857142857
# 0.7678571428571429
# 267
# optimizing B3346-U1.cas
# initial proportion: 0.6968325791855203
# 0.7375565610859729
# 0.5294117647058824
# 0.5294117647058824
# 389
# optimizing C0015-V1.cas
# initial proportion: 0.09259259259259259
# 0.34972677595628415
# 0.34972677595628415
# 390
# optimizing C0016-V1.cas
# initial proportion: 0.29411764705882354
# 0.5316455696202531
# 0.5316455696202531
# 391
# optimizing C0017-U1.cas
# initial proportion: 0.5039370078740157
# 0.5669291338582677
# 0.5669291338582677
# 392
# optimizing C0017-V1.cas
# initial proportion: 0.7333333333333333
# 0.9565217391304348
# 0.9565217391304348
# 393
# optimizing C0018-U1.cas
# initial proportion: 0.5211267605633803
# 0.6617647058823529
# 0.7058823529411765
# 0.7426470588235294
# 0.75
# 0.7426470588235294
# 394
# optimizing C0019-U1.cas
# initial proportion: 0.43609022556390975
# 0.5190839694656488
# 0.549618320610687
# 0.5877862595419847
# 0.5954198473282443
# 0.4351145038167939
# 395
# optimizing C0018-V1.cas
# initial proportion: 0.6458333333333334
# 0.8809523809523809
# 0.8809523809523809
# 396
# optimizing C0020-U1.cas
# initial proportion: 0.5348837209302325
# 0.6744186046511628
# 0.6744186046511628
# 397
# optimizing C0019-V1.cas
# initial proportion: 0.8947368421052632
# 1.0
# 1.0
# 398
# optimizing C0021-U1.cas
# initial proportion: 0.40714285714285714
# 0.4928571428571429
# 0.5
# 0.4928571428571429
# 399
# optimizing C0020-V1.cas
# initial proportion: 0.2222222222222222
# 0.5555555555555556
# 0.5555555555555556
# 400
# optimizing C0022-U1.cas
# initial proportion: 0.4076923076923077
# 0.4566929133858268
# 0.4645669291338583
# 0.4566929133858268
# 401
# optimizing C0021-V1.cas
# initial proportion: 0.125
# 0.26506024096385544
# 0.26506024096385544
# 402
# optimizing C0022-V1.cas
# initial proportion: 0.38461538461538464
# 0.6410256410256411
# 0.6666666666666666
# 0.6666666666666666
# 403
# optimizing C0023-U1.cas
# initial proportion: 0.1527777777777778
# 0.41935483870967744
# 0.41935483870967744
# 404
# optimizing C0023-V1.cas
# initial proportion: 0.13559322033898305
# 0.42105263157894735
# 0.43859649122807015
# 0.42105263157894735
# 405
# optimizing C0024-V1.cas
# initial proportion: 0.34328358208955223
# 0.47715736040609136
# 0.48223350253807107
# 0.48223350253807107
# 406
# optimizing C0024-U1.cas
# initial proportion: 0.21664275466284075
# 0.28810408921933084
# 0.2899628252788104
# 0.28810408921933084
# 407
# optimizing C0025-U1.cas
# initial proportion: 0.4594594594594595
# 0.5855855855855856
# 0.5855855855855856
# 408
# optimizing C0025-V1.cas
# initial proportion: 0.9
# 0.9
# 0.9
# 409
# optimizing C0026-V1.cas
# initial proportion: 0.4528301886792453
# 0.5283018867924528
# 0.5283018867924528
# 410
# optimizing C0026-U1.cas
# initial proportion: 0.49230769230769234
# 0.6153846153846154
# 0.6153846153846154
# 411
# optimizing C0027-V1.cas
# initial proportion: 0.26855123674911663
# 0.3574007220216607
# 0.33935018050541516
# 412
# optimizing C0027-U1.cas
# initial proportion: 0.4074074074074074
# 0.5925925925925926
# 0.5740740740740741
# 413
# optimizing C0028-V1.cas
# initial proportion: 0.56
# 0.72
# 0.76
# 0.76
# 414
# optimizing C0028-U1.cas
# initial proportion: 0.4523809523809524
# 0.6428571428571429
# 0.6428571428571429
# 415
# optimizing C0029-U1.cas
# initial proportion: 0.3732394366197183
# 0.5223880597014925
# 0.5223880597014925
# 416
# optimizing C0029-V1.cas
# initial proportion: 0.18354430379746836
# 0.3037974683544304
# 0.310126582278481
# 0.3227848101265823
# 0.2974683544303797
# 417
# optimizing C0030-U1.cas
# initial proportion: 0.6075949367088608
# 0.6337579617834395
# 0.60828025477707
# 418
# optimizing C0030-V1.cas
# initial proportion: 0.8529411764705882
# 0.90625
# 0.90625
# 419
# optimizing C0031-U1.cas
# initial proportion: 0.2948717948717949
# 0.5540540540540541
# 0.5540540540540541
# 420
# optimizing C0031-V1.cas
# initial proportion: 0.3655913978494624
# 0.4810810810810811
# 0.4702702702702703
# 421
# optimizing C0032-U1.cas
# initial proportion: 0.44
# 0.5733333333333334
# 0.5733333333333334
# 422
# optimizing C0032-V1.cas
# initial proportion: 0.05172413793103448
# 0.27586206896551724
# 0.27586206896551724
# 423
# optimizing C0033-U1.cas
# initial proportion: 0.20887991927346114
# 0.23692636072572038
# 0.23692636072572038
# 424
# optimizing C0033-V1.cas
# initial proportion: 0.17441120305537874
# 0.213078618662748
# 0.21381337252020574
# 0.213078618662748
# 425
# optimizing C0034-U1.cas
# initial proportion: 0.2775800711743772
# 0.5037037037037037
# 0.5074074074074074
# 0.5074074074074074
# 426
# optimizing C0034-V1.cas
# initial proportion: 0.4594594594594595
# 0.6477272727272727
# 0.6818181818181818
# 0.6818181818181818
# 427
# optimizing C0035-U1.cas
# initial proportion: 0.13173076923076923
# 0.25814234016887816
# 0.2605548854041013
# 0.25814234016887816
# 428
# optimizing C0035-V1.cas
# initial proportion: 0.20977011494252873
# 0.3651376146788991
# 0.3706422018348624
# 0.3706422018348624
# 429
# optimizing C0036-V1.cas
# initial proportion: 0.06472491909385113
# 0.41690962099125367
# 0.4198250728862974
# 0.40233236151603496
# 430
# optimizing C0036-U1.cas
# initial proportion: 0.05080213903743316
# 0.4355400696864111
# 0.43902439024390244
# 0.43356643356643354
# 431
# optimizing C0037-U1.cas
# initial proportion: 0.3888888888888889
# 0.5208333333333334
# 0.5260416666666666
# 0.5260416666666666
# 432
# optimizing C0037-V1.cas
# initial proportion: 0.36283185840707965
# 0.47761194029850745
# 0.472636815920398
# 433
# optimizing C0038-U1.cas
# initial proportion: 0.3314285714285714
# 0.42528735632183906
# 0.4367816091954023
# 0.42528735632183906
# 434
# optimizing C0038-V1.cas
# initial proportion: 0.19718309859154928
# 0.30985915492957744
# 0.30985915492957744
# 435
# optimizing C0039-U1.cas
# initial proportion: 0.600896860986547
# 0.7135678391959799
# 0.7185929648241206
# 0.7135678391959799
# 436
# optimizing C0039-V1.cas
# initial proportion: 0.5159235668789809
# 0.625
# 0.6176470588235294
# 437
# optimizing C0040-U1.cas
# initial proportion: 0.19689922480620156
# 0.32941176470588235
# 0.34705882352941175
# 0.3509803921568627
# 0.34705882352941175
# 438
# optimizing C0040-V1.cas
# initial proportion: 0.3865546218487395
# 0.5508982035928144
# 0.5508982035928144
# 439
# optimizing C0041-V1.cas
# initial proportion: 0.24742268041237114
# 0.34054054054054056
# 0.3567567567567568
# 0.3621621621621622
# 0.3567567567567568
# 440
# optimizing C0041-U1.cas
# initial proportion: 0.4057971014492754
# 0.505
# 0.505
# 441
# optimizing C0042-U1.cas
# initial proportion: 0.6018518518518519
# 0.616822429906542
# 0.616822429906542
# 442
# optimizing C0042-V1.cas
# initial proportion: 0.6447368421052632
# 0.6944444444444444
# 0.6944444444444444
# 443
# optimizing C0043-V1.cas
# initial proportion: 0.09090909090909091
# 0.24728260869565216
# 0.2561307901907357
# 0.2670299727520436
# 0.26975476839237056
# 0.28610354223433243
# 0.29155313351498635
# 0.28610354223433243
# 444
# optimizing C0043-U1.cas
# initial proportion: 0.014557670772676373
# 0.3519061583577713
# 0.36656891495601174
# 0.3255131964809384
# 445
# optimizing C0044-V1.cas
# initial proportion: 0.3274336283185841
# 0.4107142857142857
# 0.39285714285714285
# 446
# optimizing C0044-U1.cas
# initial proportion: 0.2857142857142857
# 0.35714285714285715
# 0.35714285714285715
# 447
# optimizing C0045-V1.cas
# initial proportion: 0.14583333333333334
# 0.3484042553191489
# 0.3537234042553192
# 0.3660477453580902
# 0.34574468085106386
# 448
# optimizing C0045-U1.cas
# initial proportion: 0.10564663023679417
# 0.31754874651810583
# 0.3388888888888889
# 0.3398328690807799
# 0.3649025069637883
# 0.3593314763231198
# 449
# optimizing C0046-U1.cas
# initial proportion: 0.43209876543209874
# 0.5194805194805194
# 0.5238095238095238
# 0.5194805194805194
# 450
# optimizing C0047-U1.cas
# initial proportion: 0.43
# 0.6979166666666666
# 0.6875
# 451
# optimizing C0046-V1.cas
# initial proportion: 0.12244897959183673
# 0.34408602150537637
# 0.3333333333333333
# 452
# optimizing C0048-U1.cas
# initial proportion: 0.34782608695652173
# 0.5344827586206896
# 0.5344827586206896
# 453
# optimizing C0047-V1.cas
# initial proportion: 0.6938775510204082
# 0.8297872340425532
# 0.851063829787234
# 0.851063829787234
# 454
# optimizing C0048-V1.cas
# initial proportion: 0.49107142857142855
# 0.7567567567567568
# 0.7567567567567568
# 455
# optimizing C0049-V1.cas
# initial proportion: 0.65
# 0.7361111111111112
# 0.7361111111111112
# 456
# optimizing C0049-U1.cas
# initial proportion: 0.27921092564491656
# 0.3125948406676783
# 0.3095599393019727
# 457
# optimizing C0050-U1.cas
# initial proportion: 0.3375
# 0.5335463258785943
# 0.536741214057508
# 0.5431309904153354
# 0.5463258785942492
# 0.5463258785942492
# 458
# optimizing C0051-U1.cas
# initial proportion: 0.40384615384615385
# 0.6730769230769231
# 0.7115384615384616
# 0.7115384615384616
# 459
# optimizing C0050-V1.cas
# initial proportion: 0.6186440677966102
# 0.6727272727272727
# 0.6727272727272727
# 460
# optimizing C0051-V1.cas
# initial proportion: 0.6509433962264151
# 0.7358490566037735
# 0.7452830188679245
# 0.7735849056603774
# 0.7735849056603774
# 461
# optimizing C0052-U1.cas
# initial proportion: 0.38144329896907214
# 0.6288659793814433
# 0.7010309278350515
# 0.6907216494845361
# 462
# optimizing C0053-U1.cas
# initial proportion: 0.4489795918367347
# 0.6049382716049383
# 0.6337448559670782
# 0.6419753086419753
# 0.6460905349794238
# 0.6502057613168725
# 0.6419753086419753
# 463
# optimizing C0052-V1.cas
# initial proportion: 0.3870967741935484
# 0.5487364620938628
# 0.5523465703971119
# 0.5523465703971119
# 464
# optimizing C0054-U1.cas
# initial proportion: 0.3501683501683502
# 0.48936170212765956
# 0.5141843971631206
# 0.5141843971631206
# 465
# optimizing C0053-V1.cas
# initial proportion: 0.34096692111959287
# 0.4300254452926209
# 0.4300254452926209
# 466
# optimizing C0055-U1.cas
# initial proportion: 0.37261146496815284
# 0.49019607843137253
# 0.5130718954248366
# 0.5228758169934641
# 0.5163398692810458
# 467
# optimizing C0054-V1.cas
# initial proportion: 0.40384615384615385
# 0.5911330049261084
# 0.6305418719211823
# 0.6305418719211823
# 468
# optimizing C0056-U1.cas
# initial proportion: 0.5
# 0.7222222222222222
# 0.7
# 469
# optimizing C0055-V1.cas
# initial proportion: 0.40425531914893614
# 0.6077586206896551
# 0.6206896551724138
# 0.625
# 0.6206896551724138
# 470
# optimizing C0057-U1.cas
# initial proportion: 0.371900826446281
# 0.7603305785123967
# 0.7355371900826446
# 471
# optimizing C0056-V1.cas
# initial proportion: 0.36752136752136755
# 0.6347826086956522
# 0.6434782608695652
# 0.6434782608695652
# 472
# optimizing C0057-V1.cas
# initial proportion: 0.29411764705882354
# 0.6268656716417911
# 0.6567164179104478
# 0.6716417910447762
# 0.6716417910447762
# 473
# optimizing C0058-U1.cas
# initial proportion: 0.5135135135135135
# 0.7377049180327869
# 0.73224043715847
# 474
# optimizing C0059-U1.cas
# initial proportion: 0.3497854077253219
# 0.4012875536480687
# 0.41630901287553645
# 0.4270386266094421
# 0.4184549356223176
# 475
# optimizing C0058-V1.cas
# initial proportion: 0.37423312883435583
# 0.63125
# 0.63125
# 476
# optimizing C0060-U1.cas
# initial proportion: 0.2770780856423174
# 0.42710997442455245
# 0.41687979539641945

# %%
pd.DataFrame({'offsets':offsets, 'slopes':slopes, 'names':files, 'indices':indices}).to_csv('../data/updated_calibration_new_1900_first_beyond_1434.csv', index=False)

# %%
pd.read_csv('../data/updated_calibration_new_1900_first_beyond_1434.csv')
# Out:
#       offsets        slopes         names  indices
# 0    0.001505  1.549451e-07  B1750-U1.cas     1435
# 1   -0.001505  1.549451e-07  B1749-V1.cas     1436
# 2    0.001505  1.549451e-07  B1750-V1.cas     1437
# 3    0.000121  1.370568e-08  B1751-U1.cas     1438
# 4    0.001505  1.549451e-07  B1751-V1.cas     1439
# ..        ...           ...           ...      ...
# 472  0.000027 -8.527342e-05  C0057-V1.cas     1907
# 473 -0.000947  1.000000e-07  C0058-U1.cas     1908
# 474 -0.001637 -5.272632e-05  C0059-U1.cas     1909
# 475 -0.000682  4.505495e-08  C0058-V1.cas     1910
# 476 -0.000685 -1.000000e-07  C0060-U1.cas     1911
#
# [477 rows x 4 columns]
